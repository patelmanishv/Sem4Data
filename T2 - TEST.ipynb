# %% [markdown]
# <center> <h1> PYTHON - 2 T2 CLASS TEST </h1> </center>
#
# ## MCQS - 10 MARKS

# %% [markdown]
# ## 1 Consider the following code snippet that implements linear regression in Python, what will be printed as the output of the code snippet?
#
# ```python
# import numpy as np
# from sklearn.linear_model import LinearRegression
#
# # Training data
# X_train = np.array([[1], [2], [3], [4]])
# y_train = np.array([2, 4, 6, 8])
#
# # Test data
# X_test = np.array([[5]])
#
# # Linear regression model
# model = LinearRegression( )
# model.fit(X_train, y_train)
# predicted_value = model.predict(X_test)
#
# print(predicted_value)
# ```
#
# `Prediction`
#
# A. 10
# B. [10]
# C. 5
# D. [5]
#
#
#
#
# ## 2 Consider the following lines of code having 300 non-null data in both x and y.
# What is the output of the following code:
#
# ```python
# import pandas as pd
# import numpy as np
# dataset = pd.read_csv("Book1.csv")
# x = dataset[["cgpa"]]
# y = dataset["package"]
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
# print(x_train.shape)
# ```
#
# | Output   |
# |----------|
# | A. (240,3) |
# | B. (240,)  |
# | C. (240,1) |
# | D. (60,)   |
#
#
# ## 3 What does the following code snippet accomplish?
#
# ```python
# from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsClassifier
#
# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
# knn = KNeighborsClassifier(n_neighbors=5)
# knn.fit(X_train, y_train)
# predicted_labels = knn.predict(X_test)
# ```
#
# | Description                                                                                                               |
# |---------------------------------------------------------------------------------------------------------------------------|
# | A. Initializes a kNN classifier with 5 neighbors and trains it on the entire dataset                                      |
# | B. Splits the dataset into training and testing sets, initializes a kNN classifier with 5 neighbors, and trains it on the training set |
# | C. Trains a decision tree classifier with Gini index as the criterion                                                     |
# | D. Initializes a logistic regression classifier and evaluates its performance on the test set                             |
#
# ## 4 What class from scikit-learn is used to create a KNN classifier?
#
# | Class                   |
# |-------------------------|
# | A. KNeighborsRegressor()|
# | B. KNeighborsClassifier()|
# | C. knn_classify()       |
# | D. nearest_neighbors()  |
#
# ## 5 What metric is used by default in KNeighborsClassifier() to calculate distance between data points?
#
# | Metric            |
# |-------------------|
# | A. Manhattan distance|
# | B. Chebyshev distance|
# | C. Euclidean distance |
# | D. Jaccard similarity |
#
# ## 6 What is the primary task of the k-Nearest Neighbors algorithm?
#
# | Task              |
# |-------------------|
# | A. Classification |
# | B. Regression     |
# | C. Clustering     |
# | D. Dimensionality reduction |
#
# ## 7 In kNN, the value of k represents:
#
# | Representation                |
# |-------------------------------|
# | A. The number of features in the dataset|
# | B. The number of clusters in the dataset|
# | C. The number of nearest neighbors to consider|
# | D. The number of classes in the dataset|
#
# ## 8: What is the purpose of the following code snippet?
#
# ```python
# from sklearn.metrics import confusion_matrix
# conf_matrix = confusion_matrix(true_labels, predicted_labels)
# ```
#
# - A. Evaluating the confusion matrix
# - B. Training a decision tree classifier
# - C. Implementing kNN algorithm
# - D. Tuning hyperparameters for a random forest classifier
#
#
# ## 9: What does the following code snippet accomplish?
#
# ```python
# print(conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[0, 1]))
# ```
#
# - A. Calculating the sensitivity of the classifier
# - B. Calculating the specificity of the classifier
# - C. Evaluating the F1 score
# - D. Printing the accuracy score of the model
#
# ## 10: **What is the purpose of the following code snippet?**
#
# ```python
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import confusion_matrix
#
# dt_classifier = DecisionTreeClassifier(criterion='entropy')
# dt_classifier.fit(X_train, y_train)
# predicted_labels = dt_classifier.predict(X_test)
# conf_matrix = confusion_matrix(y_test, predicted_labels)
# ```
#
# - A. Initializes a decision tree classifier with entropy as the criterion and evaluates its performance using a confusion matrix
# - B. Initializes a kNN classifier with 3 neighbors and evaluates its performance using a confusion matrix
# - C. Initializes a logistic regression classifier and evaluates its performance using a confusion matrix
# - D. Trains a random forest classifier and evaluates its performance using a confusion matrix

# %% [markdown]
# ## Q - 2(A) (3 Marks)

# %% [markdown]
# > **You've been given a dataset with apartment area and price information. There's a noticeable non-linear relationship between area and price. To address this you intend to categorize them into 'High', 'Medium', and 'Low' groups. Prices above \\$3,000,000 are 'High', below \\$2,000,000 are 'Low', and between \\$2,000,000 and \\$3,000,000 are 'Medium'. Write a code to achieve this assuming that dataset has two columns named area and price.**

# %% [markdown]
# ## Q - 2(B) (3 Marks)

# %% [markdown]
# > **Write Python code to train a decision tree classifier with entropy as the criterion using the following steps:
# Initialize a Decision Tree classifier with entropy as the criterion.
# Train the classifier on the training set.
# Make predictions on the test set.
# Calculate and print the confusion matrix for the classifier.**

# %% [markdown]
# ## Q - 3 (9 marks)

# %% [markdown]
# # Simple and Multiple Linear Regression
#
#
# [Dataset](https://raw.githubusercontent.com/patelmanishv/Sem4Data/main/Data/50_Startups.csv)
#
# - Split the dataset with 75% training size and 25% testing size and random state of 0 for both the cases.
#
# - Fit simple linear Fit multiple linear regression and find mse, r2 score, intercept and coefficient of the model. Also display the regression plot. The variables are as follows -
#
# - **Dependent Variable** - Profit
# - **Independent Variable** - R&D Spend
#
# - Fit multiple linear regression and find mse, r2 score, intercept and coefficient of the model. The variables are as follows -
#
# - **Dependent Variable** - Profit
# - **Independent Variables** - R&D Spend,Administration,Marketing Spend, State

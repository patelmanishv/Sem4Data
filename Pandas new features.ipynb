# %% [markdown]
# ## PANDAS TRANSFORMATION

# %% [markdown]
# ## IMPORT LIBRARIES

# %% [markdown]
# ## CREATE DATAFRAME

# %% [markdown]
# ### df.apply()
# ![pandas-dataframe-apply-1.png](attachment:d057a901-9594-4cf3-ac7c-e6c729a82b50.png)

# %% [markdown]
# ### df.astype()
# ![download.png](attachment:acd64a37-d5c3-46c3-b6f4-d99773855f06.png)

# %% [markdown]
# ### df.replace()
# ![image.png](attachment:9382e507-a043-4d3f-b82b-f4bd1eab9365.png)

# %% [markdown]
# ### MERGE VS CONCAT
# ![1_eJwlUcC4sXvemfegAgBh9w.png](attachment:55588b5e-30e7-49ab-b692-ca2d033e5295.png)

# %% [markdown]
# ### df.concat(axis = 0/1)
# ![image.png](attachment:7f8ea1ed-435c-474c-9490-7b0ef685bbe2.png)![image.png](attachment:524ae0bd-452b-4997-990d-fa560fed3418.png)

# %% [markdown]
# ### df.concat(join = inner/outer)
# ![image.png](attachment:a2a9c8f9-08e1-4503-81c0-c9e9e1add5ea.png)![image.png](attachment:6f5b2126-8e79-4419-804f-f96a844a8ca7.png)

# %% [markdown]
# ### pd.concat(ignore_index = True)
# ![pandas_concat_dataframes_ignore_index.png](attachment:ada7323c-0108-4cc8-bae4-fb520d318984.png)

# %% [markdown]
# ### df.concat(sort=True/False)

# %% [markdown]
# ### df.merge(how = "inner/outer")
# ![image.png](attachment:2b83ff7e-c0b9-4f4a-a3b5-ab5c10f639a1.png)![image.png](attachment:f839f6dd-2417-4ae6-8abe-b37e67dd991b.png)

# %% [markdown]
# ## pd.merge(left_on/right_on)
# ![image.png](attachment:34e10670-f3c8-42d8-b126-204a2f47f374.png)![image.png](attachment:1cc95d72-f77d-40e9-a9ee-5b04e346c29e.png)

# %% [markdown]
# ### pd.merge(left_index,right_index)
# ![merge-two-dataframes-on-index-pandas-duplicated-indexes.png](attachment:59cad603-5ad0-4c6e-9695-83516546c912.png)

# %% [markdown]
# ### df.merge(sort=True)

# %% [markdown]
# ### df.merge(suffixes=())

# %% [markdown]
# ## GROUPBY
#
# ![image.png](attachment:847910ea-2532-4a6a-99b0-64fb13bcaa3d.png)
#
# ![image.png](attachment:a6dd225b-d808-4fd0-b67d-6eafcc329df2.png)![image.png](attachment:ba1023f2-54b1-4a98-9476-371e065da2e2.png)
# ![image.png](attachment:14c63752-8145-4170-8ce2-acd5367fdf14.png)![image.png](attachment:4ae65624-b90a-4f51-9319-8fff1f960212.png)
#
# ![image.png](attachment:291467ca-9518-49d3-828a-026d8fd817a9.png)![image.png](attachment:b7959889-e1a8-42e7-8c71-d7debb8fd638.png)
# ![image.png](attachment:48d20f34-0aa6-4b3b-b886-2ad651ed8de7.png)![image.png](attachment:d386076b-b97c-42dc-ad88-cf7c42baa29a.png)

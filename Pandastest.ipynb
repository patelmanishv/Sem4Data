# %% [markdown]
# <center><h1> TITANIC DATA ANALYSIS</h1></center>

# %% [markdown]
# ## IMPORT PANDAS AND READ DATA
# [dataset](https://raw.githubusercontent.com/patelmanishv/Sem4Data/main/Data/train.csv)

# %% [markdown]
# ## CHECK 10 TOPMOST DATA ENTRIES

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## CHECK SHAPE

# %% [markdown]
# ## CHECK INFO

# %% [markdown]
# ## RUN STATISTICAL ANALYSIS

# %% [markdown]
# ## RUN STATISTICAL ANALYSIS OF CATEGORICAL DATA

# %% [markdown]
# ## CHECK DATATYPES

# %% [markdown]
# ## CHECK DUPLICATES

# %% [markdown]
# ## CHECK NULL VALUES

# %% [markdown]
# ## BOXPLOT FOR FARES CATEGORY

# %% [markdown]
# ## CREATE CORRELATION MATRIX

# %% [markdown]
# ## CREATE HEATMAP OF CORRELATION MATRIX

# %% [markdown]
# ## REMOVE OUTLIERS FROM FARES CATEGORY

# %% [markdown]
# <!-- __here__ -->
# <hr style="border:2px solid gray">
#
# <!-- import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Assuming 'df' is your DataFrame
# df = pd.read_csv("https://raw.githubusercontent.com/patelmanishv/Sem4Data/main/Data/train.csv")
# # Run Statistical Analysis
# print(df.describe())
# print(df.describe(include=['object']))
#
# # Run Statistical Analysis of Categorical Data
# for col in df.select_dtypes(include=['object']):
#     print(df[col].value_counts())
#
# # Check Data Types
# print(df.dtypes)
#
# # Check Duplicates
# print(df.duplicated().sum())
#
# # Check Null Values
# print(df.isnull().sum())
#
# # Boxplot for Fares Category
# plt.figure(figsize=(8, 6))
# df.boxplot(column='Fare')
# plt.title('Boxplot of Fares')
# plt.show()
#
# # Create Correlation Matrix
# correlation_matrix = df.corr(numeric_only=True)
# print(correlation_matrix)
#
# # Create Heatmap of Correlation Matrix
# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Matrix Heatmap')
# plt.show()
#
# # Remove Outliers from Fares Category
# def remove_outliers_iqr(df, column):
#     Q1 = df[column].quantile(0.25)
#     Q3 = df[column].quantile(0.75)
#     IQR = Q3 - Q1
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#     df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
#     return df_filtered
#
# df_cleaned = remove_outliers_iqr(df, 'Fare') -->
